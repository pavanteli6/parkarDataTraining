# %%
# %sql
SELECT "Hello world from SQL!"

# %%
# %sql
-- Databricks notebook source
CREATE TABLE employeespavan
  (id INT, name STRING, salary DOUBLE);

# %%
# %sql

INSERT INTO employeespavan
VALUES 
  (1, "Adam", 3500.0),
  (2, "Sarah", 4020.5),
  (3, "John", 2999.3),
  (4, "Thomas", 4000.3),
  (5, "Anna", 2500.0),
  (6, "Kim", 6200.3)

# %%
# %sql
-- COMMAND ----------

SELECT * FROM employeespavan

-- COMMAND ----------

# %%
# %sql
DESCRIBE DETAIL employeespavan

-- COMMAND ----------

# %%
# %sql

-- COMMAND ----------

SELECT 'dbfs:/user/hive/warehouse/employeespavan'

# %%
# %sql
-- COMMAND ----------

UPDATE employeespavan
SET salary = salary + 100
WHERE name LIKE "A%"

# %%
# %sql
-- COMMAND ----------

SELECT * FROM employeespavan

# %%
# %sql

-- COMMAND ----------

DESCRIBE DETAIL employeespavan

# %%
# %sql

-- COMMAND ----------

DESCRIBE HISTORY employeespavan
