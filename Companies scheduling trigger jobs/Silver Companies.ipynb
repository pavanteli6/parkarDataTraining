# %%
# %sql
-- Databricks notebook source
CREATE SCHEMA IF NOT EXISTS pavan_companies.silver
     MANAGED LOCATION 'abfss://landing@parkaru15sa.dfs.core.windows.net/';

# %%
# %sql
DROP TABLE IF EXISTS pavan_companies.silver.companies;

# %%
# %sql
CREATE TABLE pavan_companies.silver.companies
  (company_id   BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
   company_name STRING,
   founded_date DATE,
   founded_year INT GENERATED ALWAYS AS (YEAR(founded_date)),
   country      STRING);

INSERT INTO pavan_companies.silver.companies 
(company_name, founded_date, country)
SELECT company_name,
       founded_date,
       country
  FROM pavan_companies.bronze.companies;
