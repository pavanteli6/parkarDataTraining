# %%
# %sql
use catalog newpavancatalog;
use schema bronze;

# %%
# %sql
CREATE EXTERNAL LOCATION if not EXISTS pavan_external_location_circuit_box
URL 'abfss://circuitbox@parkaru15sa.dfs.core.windows.net/landing/operational_data'
WITH (CREDENTIAL pavannewaccessconnctor);

# %%
# %fs ls 'abfss://circuitbox@parkaru15sa.dfs.core.windows.net/landing/'

# %%
# %sql
CREATE CATALOG IF NOT EXISTS circuitbox_pavan
  MANAGED LOCATION 'abfss://circuitbox@parkaru15sa.dfs.core.windows.net/'
  COMMENT 'Catalog for the circuitbox data lakehouse';

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
USE CATALOG circuitbox_pavan;

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS landingSchema
   MANAGED LOCATION 'abfss://circuitbox@parkaru15sa.dfs.core.windows.net/landing';

CREATE SCHEMA IF NOT EXISTS lakehouseSchema
   MANAGED LOCATION 'abfss://circuitbox@parkaru15sa.dfs.core.windows.net/lakehouse';

# %%
# %sql

SHOW SCHEMAS;

# %%
# %sql

USE CATALOG circuitbox_pavan;
USE SCHEMA landingSchema;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data_volume
      LOCATION 'abfss://circuitbox@parkaru15sa.dfs.core.windows.net/landing/operational_data';
