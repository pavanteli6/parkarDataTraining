-- %%
DESCRIBE EXTENDED newpavancatalog.delta_lake.companies;

-- %%
%python
%fs ls 'abfss://landing@parkaru15sa.dfs.core.windows.net/delta_lake/__unitystorage/schemas/00160f3a-0ac4-4ceb-9d30-6aca38774e9a'

-- %%
CREATE TABLE IF NOT EXISTS newpavancatalog.delta_lake.companies
  (company_name STRING,
   founded_date DATE,
   country      STRING);

-- %%
select * from newpavancatalog.delta_lake.companies
