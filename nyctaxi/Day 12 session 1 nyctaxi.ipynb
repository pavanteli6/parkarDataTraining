-- %%
%sql
select current_metastore()

-- %%
%sql
use catalog newpavancatalog;
use schema bronze;

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS pavannewexternallocation
    URL 'abfss://landing@parkaru15sa.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL pavannewaccessconnctor)
    COMMENT 'External Location for yellow taxi nyc Purposes'

-- %%
%sql
show external locations;

-- %%
%sql
DESCRIBE EXTERNAL LOCATION pavannewexternallocation;

-- %%
%fs ls 'abfss://landing@parkaru15sa.dfs.core.windows.net/nyctaxi/'

-- %%
%sql

USE CATALOG newpavancatalog;
USE SCHEMA bronze;

-- %%
-- DROP VOLUME IF EXISTS operational_data_volume;

-- %%
%sql
CREATE EXTERNAL VOLUME IF NOT EXISTS nyc_taxi_data_volume
      LOCATION 'abfss://landing@parkaru15sa.dfs.core.windows.net/nyctaxi';

-- %%
-- /Volumes/newpavancatalog/bronze/nyc_taxi_data_volume
